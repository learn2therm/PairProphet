# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy.stats
import sklearn.preprocessing
import sklearn.model_selection
import sklearn.ensemble
import sklearn.feature_selection
import unittest
from sklearn.datasets import load_digits

# %%
digits = load_digits()
data = digits.data
data.shape
# Out:
# (1797, 64)

# %%
#taking a sample image to view
#Remember image is in the form of numpy array.
image_sample = data[0,:].reshape(8,8)
plt.imshow(image_sample)

# %%
#Import required modules
from sklearn.decomposition import PCA
 
pca = PCA(2) # we need 2 principal components.
converted_data = pca.fit_transform(digits.data)
 
converted_data.shape
# Out:
# (1797, 2)

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize = (10,6))
c_map = plt.cm.get_cmap('jet', 10)
plt.scatter(converted_data[:, 0], converted_data[:, 1], s = 15,
            cmap = c_map , c = digits.target)
plt.colorbar()
plt.xlabel('PC-1') , plt.ylabel('PC-2')
plt.show()

# %% [markdown]
# Pillow

# %%
from PIL import Image

# Open the image file
img_1 = Image.open("/Users/loganroberts/Documents/Mycobacterium_tb.png")

# # Display the image
# img.show()

# %%
img_array_1 = np.array(img)
img_array_1.shape
# Out:
# (386, 332, 3)

# %% [markdown]
# OpenCV

# %%
import cv2

# %%
# Loading the image 
img_2 = cv2.imread('/Users/loganroberts/Documents/Mycobacterium_tb.png') #you can use any image you want.
plt.imshow(img)

# %%
# Splitting the image in R,G,B arrays.
 
blue,green,red = cv2.split(img_2)

# %%
#initialize PCA with first 20 principal components
pca = PCA(20)
 
#Applying to red channel and then applying inverse transform to transformed array.
red_transformed = pca.fit_transform(red)
red_inverted = pca.inverse_transform(red_transformed)
 
#Applying to Green channel and then applying inverse transform to transformed array.
green_transformed = pca.fit_transform(green)
green_inverted = pca.inverse_transform(green_transformed)
 
#Applying to Blue channel and then applying inverse transform to transformed array.
blue_transformed = pca.fit_transform(blue)
blue_inverted = pca.inverse_transform(blue_transformed)

# %%
img_compressed_2 = (np.dstack((red_inverted, red_inverted, red_inverted))).astype(np.uint8)

# %%
#viewing the compressed image
plt.imshow(img_compressed_2)

# %%
img_compressed_2.shape
# Out:
# (386, 332, 3)

# %%
img_compressed_2.flatten()
# Out:
# array([255, 255, 255, ..., 255, 255, 255], dtype=uint8)

# %%
len(img_compressed_2)
# Out:
# 386
